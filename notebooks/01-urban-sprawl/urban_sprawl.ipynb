# %% [markdown]
# # Urban Sprawl Detector
#
# **Plan doc:** [`docs/plans/level-1-notebooks/01-urban-sprawl-detector.md`](../../docs/plans/level-1-notebooks/01-urban-sprawl-detector.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Visualise AOIs, cloud stats, temporal S2 coverage

# %%
# TODO: Data Exploration — Visualise AOIs, cloud stats, temporal S2 coverage

# %% [markdown]
# ## 2. Feature Engineering — Compute NDBI, NDVI, BSI change indices; create bi-temporal chip pairs

# %%
# TODO: Feature Engineering — Compute NDBI, NDVI, BSI change indices; create bi-temporal chip pairs

# %% [markdown]
# ## 3. Labeling Pipeline — Generate NDBI pseudo-labels; guide for manual correction in QGIS

# %%
# TODO: Labeling Pipeline — Generate NDBI pseudo-labels; guide for manual correction in QGIS

# %% [markdown]
# ## 4. Baseline Models — NDBI threshold & Random Forest benchmarks

# %%
# TODO: Baseline Models — NDBI threshold & Random Forest benchmarks

# %% [markdown]
# ## 5. Siamese U-Net Training — Full model training + hyperparameter tuning

# %%
# TODO: Siamese U-Net Training — Full model training + hyperparameter tuning

# %% [markdown]
# ## 6. Evaluation — IoU, F1, confusion matrix, visual results per city

# %%
# TODO: Evaluation — IoU, F1, confusion matrix, visual results per city

# %% [markdown]
# ## 7. Inference Demo — Run on new dates, export GeoTIFF predictions

# %%
# TODO: Inference Demo — Run on new dates, export GeoTIFF predictions
