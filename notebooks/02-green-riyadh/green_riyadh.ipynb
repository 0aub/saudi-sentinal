# %% [markdown]
# # Green Riyadh Monitor
#
# **Plan doc:** [`docs/plans/level-1-notebooks/02-green-riyadh-monitor.md`](../../docs/plans/level-1-notebooks/02-green-riyadh-monitor.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — NDVI/SAVI maps, seasonal patterns, cloud frequency

# %%
# TODO: Data Exploration — NDVI/SAVI maps, seasonal patterns, cloud frequency

# %% [markdown]
# ## 2. Monthly Composites — Build cloud-free monthly median composites 2019–2024

# %%
# TODO: Monthly Composites — Build cloud-free monthly median composites 2019–2024

# %% [markdown]
# ## 3. Vegetation Classification — Threshold-based 4-class SAVI maps

# %%
# TODO: Vegetation Classification — Threshold-based 4-class SAVI maps

# %% [markdown]
# ## 4. Trend Analysis Baseline — Mann-Kendall test + linear regression

# %%
# TODO: Trend Analysis Baseline — Mann-Kendall test + linear regression

# %% [markdown]
# ## 5. LSTM Trend Model — Train Bi-LSTM on 60-month SAVI time-series

# %%
# TODO: LSTM Trend Model — Train Bi-LSTM on 60-month SAVI time-series

# %% [markdown]
# ## 6. Spatial Analysis — Aggregate trends to Riyadh neighbourhoods/districts

# %%
# TODO: Spatial Analysis — Aggregate trends to Riyadh neighbourhoods/districts

# %% [markdown]
# ## 7. Green Riyadh Report — Final maps, stats, initiative progress assessment

# %%
# TODO: Green Riyadh Report — Final maps, stats, initiative progress assessment
