# %% [markdown]
# # Crop Type Mapping
#
# **Plan doc:** [`docs/plans/level-1-notebooks/03-crop-type-mapping.md`](../../docs/plans/level-1-notebooks/03-crop-type-mapping.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Visualise farms, NDVI profiles, seasonal patterns

# %%
# TODO: Data Exploration — Visualise farms, NDVI profiles, seasonal patterns

# %% [markdown]
# ## 2. Pivot Detection — Hough Transform circle detection on annual max NDVI

# %%
# TODO: Pivot Detection — Hough Transform circle detection on annual max NDVI

# %% [markdown]
# ## 3. Temporal Profiles — Extract and cluster NDVI time-series per farm

# %%
# TODO: Temporal Profiles — Extract and cluster NDVI time-series per farm

# %% [markdown]
# ## 4. Labeling & Dataset — Label farms, create spatial train/val/test split

# %%
# TODO: Labeling & Dataset — Label farms, create spatial train/val/test split

# %% [markdown]
# ## 5. Baseline RF — Random Forest on phenology features

# %%
# TODO: Baseline RF — Random Forest on phenology features

# %% [markdown]
# ## 6. Temporal Attention Network Training — TANet on monthly stacks

# %%
# TODO: Temporal Attention Network Training — TANet on monthly stacks

# %% [markdown]
# ## 7. Evaluation — Per-class accuracy, confusion matrix, crop type maps

# %%
# TODO: Evaluation — Per-class accuracy, confusion matrix, crop type maps

# %% [markdown]
# ## 8. Full Region Inference — Run on all AOIs, export crop type GeoTIFFs

# %%
# TODO: Full Region Inference — Run on all AOIs, export crop type GeoTIFFs
