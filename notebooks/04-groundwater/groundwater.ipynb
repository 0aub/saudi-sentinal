# %% [markdown]
# # Groundwater Depletion Tracker
#
# **Plan doc:** [`docs/plans/level-1-notebooks/04-groundwater-depletion-tracker.md`](../../docs/plans/level-1-notebooks/04-groundwater-depletion-tracker.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Visualise farm regions, count visible pivot farms

# %%
# TODO: Data Exploration — Visualise farm regions, count visible pivot farms

# %% [markdown]
# ## 2. Annual Composites — Peak-season (Feb–Apr) NDVI composites 2019–2024

# %%
# TODO: Annual Composites — Peak-season (Feb–Apr) NDVI composites 2019–2024

# %% [markdown]
# ## 3. Farm Detection — NDVI threshold + morphological cleaning

# %%
# TODO: Farm Detection — NDVI threshold + morphological cleaning

# %% [markdown]
# ## 4. Change Detection — Year-over-year farm appearance/disappearance classification

# %%
# TODO: Change Detection — Year-over-year farm appearance/disappearance classification

# %% [markdown]
# ## 5. Trend Analysis — Per-region depletion statistics and rate of loss

# %%
# TODO: Trend Analysis — Per-region depletion statistics and rate of loss

# %% [markdown]
# ## 6. Anomaly Autoencoder — LSTM-AE for early warning on at-risk farms

# %%
# TODO: Anomaly Autoencoder — LSTM-AE for early warning on at-risk farms

# %% [markdown]
# ## 7. Regional Report — Maps, charts, policy-relevant statistics

# %%
# TODO: Regional Report — Maps, charts, policy-relevant statistics
