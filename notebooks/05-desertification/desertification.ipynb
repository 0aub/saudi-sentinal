# %% [markdown]
# # Desertification Early Warning
#
# **Plan doc:** [`docs/plans/level-1-notebooks/05-desertification-warning.md`](../../docs/plans/level-1-notebooks/05-desertification-warning.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Visualise agri margins, S1+S2 temporal coverage

# %%
# TODO: Data Exploration — Visualise agri margins, S1+S2 temporal coverage

# %% [markdown]
# ## 2. Feature Engineering — Compute all 14 optical + SAR + topographic features

# %%
# TODO: Feature Engineering — Compute all 14 optical + SAR + topographic features

# %% [markdown]
# ## 3. Labeling — Define risk zones, generate labelled pixel dataset

# %%
# TODO: Labeling — Define risk zones, generate labelled pixel dataset

# %% [markdown]
# ## 4. EDA Features — Distributions, correlations, feature importance preview

# %%
# TODO: EDA Features — Distributions, correlations, feature importance preview

# %% [markdown]
# ## 5. Model Training — XGBoost vs RF vs LogReg comparison

# %%
# TODO: Model Training — XGBoost vs RF vs LogReg comparison

# %% [markdown]
# ## 6. Risk Map Generation — Full-AOI inference, risk score raster export

# %%
# TODO: Risk Map Generation — Full-AOI inference, risk score raster export

# %% [markdown]
# ## 7. Validation — Spatial validation against known degradation sites

# %%
# TODO: Validation — Spatial validation against known degradation sites
