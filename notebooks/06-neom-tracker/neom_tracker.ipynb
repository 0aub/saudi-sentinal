# %% [markdown]
# # NEOM Construction Tracker
#
# **Plan doc:** [`docs/plans/level-1-notebooks/06-neom-construction-tracker.md`](../../docs/plans/level-1-notebooks/06-neom-construction-tracker.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — NEOM corridor visualisation, S1+S2 coverage

# %%
# TODO: Data Exploration — NEOM corridor visualisation, S1+S2 coverage

# %% [markdown]
# ## 2. Baseline Comparison — 2020 vs 2024 visual side-by-side

# %%
# TODO: Baseline Comparison — 2020 vs 2024 visual side-by-side

# %% [markdown]
# ## 3. Change Features — Optical + SAR change feature computation

# %%
# TODO: Change Features — Optical + SAR change feature computation

# %% [markdown]
# ## 4. Labeling — Manual labelling of 4 construction phases

# %%
# TODO: Labeling — Manual labelling of 4 construction phases

# %% [markdown]
# ## 5. Fusion Model Training — Bi-temporal S1+S2 CNN

# %%
# TODO: Fusion Model Training — Bi-temporal S1+S2 CNN

# %% [markdown]
# ## 6. Evaluation — Accuracy, confusion matrix, visual phase maps

# %%
# TODO: Evaluation — Accuracy, confusion matrix, visual phase maps

# %% [markdown]
# ## 7. Progress Timeline — Monthly construction front progression animation

# %%
# TODO: Progress Timeline — Monthly construction front progression animation
