# %% [markdown]
# # Sand Dune Migration Predictor
#
# **Plan doc:** [`docs/plans/level-1-notebooks/07-sand-dune-migration.md`](../../docs/plans/level-1-notebooks/07-sand-dune-migration.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Visualise dune fields, SAR intensity patterns

# %%
# TODO: Data Exploration — Visualise dune fields, SAR intensity patterns

# %% [markdown]
# ## 2. Speckle Filtering — Lee/Gamma-MAP filter on S1 imagery

# %%
# TODO: Speckle Filtering — Lee/Gamma-MAP filter on S1 imagery

# %% [markdown]
# ## 3. NCC Displacement — Cross-correlation displacement field generation

# %%
# TODO: NCC Displacement — Cross-correlation displacement field generation

# %% [markdown]
# ## 4. Displacement Analysis — Visualise migration patterns, speeds, directions

# %%
# TODO: Displacement Analysis — Visualise migration patterns, speeds, directions

# %% [markdown]
# ## 5. Dataset Preparation — Create temporal stacks + displacement labels

# %%
# TODO: Dataset Preparation — Create temporal stacks + displacement labels

# %% [markdown]
# ## 6. ConvLSTM Training — Displacement predictor model

# %%
# TODO: ConvLSTM Training — Displacement predictor model

# %% [markdown]
# ## 7. Evaluation — Displacement error maps, directional accuracy

# %%
# TODO: Evaluation — Displacement error maps, directional accuracy
