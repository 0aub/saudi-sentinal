# %% [markdown]
# # Flash Flood Risk Mapping
#
# **Plan doc:** [`docs/plans/level-1-notebooks/08-flash-flood-risk.md`](../../docs/plans/level-1-notebooks/08-flash-flood-risk.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Jeddah wadi system, SAR coverage, known flood dates

# %%
# TODO: Data Exploration — Jeddah wadi system, SAR coverage, known flood dates

# %% [markdown]
# ## 2. DEM Features — Compute elevation, slope, TWI, HAND, flow accumulation

# %%
# TODO: DEM Features — Compute elevation, slope, TWI, HAND, flow accumulation

# %% [markdown]
# ## 3. SAR Baseline — Build per-pixel mean/std of VV backscatter

# %%
# TODO: SAR Baseline — Build per-pixel mean/std of VV backscatter

# %% [markdown]
# ## 4. Flood Detection — Threshold-based flood extent extraction from SAR

# %%
# TODO: Flood Detection — Threshold-based flood extent extraction from SAR

# %% [markdown]
# ## 5. Flood Frequency Map — Aggregate 7-year flood detections

# %%
# TODO: Flood Frequency Map — Aggregate 7-year flood detections

# %% [markdown]
# ## 6. Risk Model Training — XGBoost on topo + SAR + flood frequency

# %%
# TODO: Risk Model Training — XGBoost on topo + SAR + flood frequency

# %% [markdown]
# ## 7. Risk Map Generation — Full AOI risk map, evacuation zone delineation

# %%
# TODO: Risk Map Generation — Full AOI risk map, evacuation zone delineation
