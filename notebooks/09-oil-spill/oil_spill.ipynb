# %% [markdown]
# # Oil Spill Detection
#
# **Plan doc:** [`docs/plans/level-1-notebooks/09-oil-spill-detection.md`](../../docs/plans/level-1-notebooks/09-oil-spill-detection.md)

# %%
# Standard imports — add project-specific imports as needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../..')  # repo root on PYTHONPATH

# Level 0 Tile API URL (set in .env or docker-compose)
import os
TILE_API_URL = os.getenv('TILE_API_URL', 'http://localhost:8100')

# %% [markdown]
# ## 1. Data Exploration — Arabian Gulf SAR coverage, known spill locations

# %%
# TODO: Data Exploration — Arabian Gulf SAR coverage, known spill locations

# %% [markdown]
# ## 2. SAR Preprocessing — Calibration, land masking, speckle filtering

# %%
# TODO: SAR Preprocessing — Calibration, land masking, speckle filtering

# %% [markdown]
# ## 3. Wind Filtering — ERA5 wind speed integration, discard low-wind scenes

# %%
# TODO: Wind Filtering — ERA5 wind speed integration, discard low-wind scenes

# %% [markdown]
# ## 4. Dark Patch Detection — DeepLabV3+ for anomaly segmentation

# %%
# TODO: Dark Patch Detection — DeepLabV3+ for anomaly segmentation

# %% [markdown]
# ## 5. Feature Extraction — Shape, texture, context features per dark patch

# %%
# TODO: Feature Extraction — Shape, texture, context features per dark patch

# %% [markdown]
# ## 6. Look-Alike Classifier — Random Forest: oil vs. look-alike

# %%
# TODO: Look-Alike Classifier — Random Forest: oil vs. look-alike

# %% [markdown]
# ## 7. Evaluation — Full pipeline, false positive analysis

# %%
# TODO: Evaluation — Full pipeline, false positive analysis
